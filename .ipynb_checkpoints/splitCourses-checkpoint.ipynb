# ANT 212 Kutztown UG SHAMANS, WITCHES & MAGIC - A 3.000 12.00
# CMP 200 Kutztown UG RESEARCH AND COMPOSITION - A 3.000 12.00
# CSC 125 Kutztown UG Discrete Math for Computing I A 3.000 12.00
# CSC 223 Kutztown UG Advanced Scientific Programming A 3.000 12.00
# CSC 252 Kutztown UG UNIX Scripting and Administration A 3.000 12.00
# CSC 111 Kutztown UG Computer Forensics A 3.000 12.00
# ...

# %%
joinedText = text.replace("\n"," ")

campusText = joinedText.replace("Campus", "")
newText = campusText.replace("Kutztown", "Kutztown Campus")
# print(newText)
print(newText)
# Out:
#  TRANSFER CREDIT ACCEPTED BY INSTITUTION Fall 2021: Comm College of the Air Force Subject Course Title Grade Credit Hours Quality Points R PEC 70 PERSONAL FITNESS CR 2.000 0.00 SPT 20 FIRST AID CR 2.000 0.00 Attempt Hours Passed Hours Earned Hours GPA Hours Quality Points GPA Current Term 4.000 4.000 4.000 0.000 0.00 0.00 Fall 2021: AP Advanced Placement Subject Course Title Grade Credit Hours Quality Points R FRE 101 ELEMENTARY FRENCH I CR 3.000 0.00 FRE 102 ELEMENTARY FRENCH II CR 3.000 0.00 FRE 103 INTERMEDIATE FRENCH III CR 3.000 0.00 FRE 104 INTERMEDIATE FRENCH IV CR 3.000 0.00 FRE 212 FRENCH COMPOSITION CR 3.000 0.00 Attempt Hours Passed Hours Earned Hours GPA Hours Quality Points GPA Current Term 15.000 15.000 15.000 0.000 0.00 0.00 INSTITUTION CREDIT Term: Fall 2021 Major Computer Science Additional Standing Dean's List Subject Course  Level Title Grade Credit Quality R Hours Points CMP 100 Kutztown Campus UG Effective Composition A 3.000 12.00  CSC 135 Kutztown Campus UG COM
# ...

# %%
# split_courses = re.split(r'(?=[A-Z]{3,4} \d{1,3})', newText)
split_courses = re.split(r'(?=(?:[A-Z]{3,4} \d{1,3}))', newText)
# split_courses = re.split(r'(?=(?:[A-Z]{4} \d{1,3}|[A-Z]{3} \d{1,3}))', newText)
# Strip any leading/trailing whitespace
split_courses = [course.strip() for course in split_courses if course.strip()]
pprint(split_courses)
# Out:
# ['TRANSFER CREDIT ACCEPTED BY INSTITUTION Fall 2021: Comm College of the Air '
#  'Force Subject Course Title Grade Credit Hours Quality Points R',
#  'PEC 70 PERSONAL FITNESS CR 2.000 0.00',
#  'SPT 20 FIRST AID CR 2.000 0.00 Attempt Hours Passed Hours Earned Hours GPA '
#  'Hours Quality Points GPA Current Term 4.000 4.000 4.000 0.000 0.00 0.00 Fall '
#  '2021: AP Advanced Placement Subject Course Title Grade Credit Hours Quality '
#  'Points R',
#  'FRE 101 ELEMENTARY FRENCH I CR 3.000 0.00',
#  'FRE 102 ELEMENTARY FRENCH II CR 3.000 0.00',
#  'FRE 103 INTERMEDIATE FRENCH III CR 3.000 0.00',
#  'FRE 104 INTERMEDIATE FRENCH IV CR 3.000 0.00',
#  'FRE 212 FRENCH COMPOSITION CR 3.000 0.00 Attempt Hours Passed Hours Earned '
#  'Hours GPA Hours Quality Points GPA Current Term 15.000 15.000 15.000 0.000 '
#  '0.00 0.00 INSTITUTION CREDIT Term: Fall 2021 Major Computer Science '
#  "Additional Standing Dean's List Subject Course  Level Title Grade Credit "
#  'Quality R Hours Points',
# ...

# %%
print(len(split_courses))
# Out:
# 49
